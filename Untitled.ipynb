# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split
import scipy.stats as stats
# %matplotlib inline

# %%
df = pd.read_csv('Google-Playstore.csv\Google-Playstore.csv')
df
# Out:
#                                                App_Name  \
# 0             foodpanda - Local Food & Grocery Delivery
# 1       Tripadvisor Hotel, Flight & Restaurant Bookings
# 2                            Safeway Delivery & Pick Up
# 3                                   My CookBook Ad-Free
# 4                      Talabat: Food & Grocery Delivery
# ...                                                 ...
# 603042                                  Club Automation
# 603043                           Franklin Athletic Club
# 603044                       College Park Athletic Club
# 603045                                 Sequoia Wellness
# 603046                      ACAC FITNESS & WELLNESS APP
#
#                                     App_Id          Category  Rating  \
# 0             com.global.foodpanda.android      Food & Drink     4.4
# 1              com.tripadvisor.tripadvisor    Travel & Local     4.4
# 2                         com.safeway.shop          Shopping     4.2
# ...

# %%
df.isnull().sum()
# Out:
# App_Name                  1
# App_Id                    0
# Category                  0
# Rating                 3760
# Rating_Count           3760
# Installs                172
# Minimum_Installs        172
# Maximum_Installs          0
# Free                      0
# Price                     0
# Currency                181
# Size                      0
# Minimum_Android         491
# Developer_Id              2
# Developer_Website    179264
# Developer_Email          37
# Released              32278
# Last_Updated              0
# Content_Rating            0
# Privacy_Policy        85385
# Ad_Supported              0
# In_App_Purchases          0
# Editors_Choice            0
# dtype: int64

# %%
df_1=df.dropna()

# %%
df_1.isnull().sum()
# Out:
# App_Name             0
# App_Id               0
# Category             0
# Rating               0
# Rating_Count         0
# Installs             0
# Minimum_Installs     0
# Maximum_Installs     0
# Free                 0
# Price                0
# Currency             0
# Size                 0
# Minimum_Android      0
# Developer_Id         0
# Developer_Website    0
# Developer_Email      0
# Released             0
# Last_Updated         0
# Content_Rating       0
# Privacy_Policy       0
# Ad_Supported         0
# In_App_Purchases     0
# Editors_Choice       0
# dtype: int64

# %%
df_bnb = pd.read_csv('Google-Playstore.csv\AB_NYC_2019.csv')
df_bnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df_bnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df_retail = pd.read_csv('Google-Playstore.csv/nyc-rolling-sales.csv')
df_retail
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# ...           ...      ...            ...
# 84543        8409        5        WOODROW
# 84544        8410        5        WOODROW
# 84545        8411        5        WOODROW
# 84546        8412        5        WOODROW
# 84547        8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...

# %%
df_retail.isnull().sum()
# Out:
# Unnamed: 0                        0
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# EASE-MENT                         0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# APARTMENT NUMBER                  0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %%
c1 = df_retail['BOROUGH'] == 'Williamsburg'
